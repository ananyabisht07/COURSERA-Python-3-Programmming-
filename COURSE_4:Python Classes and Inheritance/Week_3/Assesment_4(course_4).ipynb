# %%
from IPython.display import Image

# %% [markdown]
# # **course_4_assessment_4**

# %% [markdown]
#  **Question:1**

# %%
Image("ass4(1).JPG",width=1000)

# %%
gold = {"US":46, "Fiji":1, "Great Britain":27, "Cuba":5, "Thailand":2, "China":26, "France":10}
country = ["Fiji", "Chile", "Mexico", "France", "Norway", "US"]
country_gold = []

for x in country:
    try:
        country_gold.append(gold[x])
    except Exception as e:
        country_gold.append("Did not get gold")
        
print(country_gold)
# Out:
# [1, 'Did not get gold', 'Did not get gold', 10, 'Did not get gold', 46]

# %% [markdown]
# **Question:2**

# %%
Image("ass4(2).JPG",width=1000)

# %%
di = [{"Puppies": 17, 'Kittens': 9, "Birds": 23, 'Fish': 90, "Hamsters": 49}, {"Puppies": 23, "Birds": 29, "Fish": 20, "Mice": 20, "Snakes": 7}, 
      {"Fish": 203, "Hamsters": 93, "Snakes": 25, "Kittens": 89}, {"Birds": 20, "Puppies": 90, "Snakes": 21, "Fish": 10, "Kittens": 67}]
total = 0
for diction in di:
    try:
        total = total + diction['Puppies']
    except Exception as e:
        print("Error")
print("Total number of puppies:", total)
# Out:
# Error
# Total number of puppies: 130

# %% [markdown]
# **Question:3**

# %%
Image("ass4(3).JPG",width=1000)

# %%
numb = [6, 0, 36, 8, 2, 36, 0, 12, 60, 0, 45, 0, 3, 23]
remainder = []
for num in numb:
    try:
        rem=36%num
        remainder.append(rem)
    except Exception as e:
        remainder.append("Error")
        print('Error')
print(remainder)
# Out:
# Error
# Error
# Error
# Error
# [0, 'Error', 0, 4, 0, 0, 'Error', 0, 36, 'Error', 36, 'Error', 0, 13]

# %% [markdown]
# **Question:4**

# %%
Image("ass4(4).JPG",width=1000)

# %%
lst = [2,4,10,42,12,0,4,7,21,4,83,8,5,6,8,234,5,6,523,42,34,0,234,1,435,465,56,7,3,43,23]
lst_three = []
for num in lst:
    try:
        if 3 % num == 0:
            lst_three.append(num)
    except ZeroDivisionError:
        print("Error")
print(lst_three)
# Out:
# Error
# Error
# [1, 3]

# %% [markdown]
# **Question:5**

# %%
Image("ass4(5).JPG",width=1000)

# %%
full_lst = ["ab", 'cde', 'fgh', 'i', 'jkml', 'nop', 'qr', 's', 'tv', 'wxy', 'z']
attempt = []
for elem in full_lst:
    try:
        attempt.append(elem[1])
    except Exception as e:
        attempt.append("Error")
        print('error')
print(attempt)
# Out:
# error
# error
# error
# ['b', 'd', 'g', 'Error', 'k', 'o', 'r', 'Error', 'v', 'x', 'Error']

# %% [markdown]
# **Question:6**

# %%
Image("ass4(6).JPG",width=1000)

# %%
conts = [['Spain', 'France', 'Greece', 'Portugal', 'Romania', 'Germany'], ['USA', 'Mexico', 'Canada'], ['Japan', 'China', 'Korea', 'Vietnam', 'Cambodia'], 
         ['Argentina', 'Chile', 'Brazil', 'Ecuador', 'Uruguay', 'Venezuela'], ['Australia'], ['Zimbabwe', 'Morocco', 'Kenya', 'Ethiopa', 'South Africa'], ['Antarctica']]
third_countries = []
for c in conts:
    try:
        third_countries.append(c[2])
    except Exception as e:
        third_countries.append("Continent does not have 3 countries")
        print('error')
print(third_countries)
# Out:
# error
# error
# ['Greece', 'Canada', 'Korea', 'Brazil', 'Continent does not have 3 countries', 'Kenya', 'Continent does not have 3 countries']

# %% [markdown]
# **Question:7**

# %%
Image("ass4(7).JPG",width=1000)

# %%
sport = ["hockey", "basketball", "soccer", "tennis", "football", "baseball"]
ppl_play = {"hockey":4, "soccer": 10, "football": 15, "tennis": 8}
for x in sport:
    try:
        print(ppl_play[x])
    except Exception as e:
        ppl_play[x]=1
        print('error')
print(ppl_play)
# Out:
# 4
# error
# 10
# 8
# 15
# error
# {'hockey': 4, 'soccer': 10, 'football': 15, 'tennis': 8, 'basketball': 1, 'baseball': 1}

# %% [markdown]
# **Question:8**

# %%
Image("ass4(8).JPG",width=1000)

# %%
di = [{"Puppies": 17, 'Kittens': 9, "Birds": 23, 'Fish': 90, "Hamsters": 49}, {"Puppies": 23, "Birds": 29, "Fish": 20, "Mice": 20, "Snakes": 7}, 
      {"Fish": 203, "Hamsters": 93, "Snakes": 25, "Kittens": 89}, {"Birds": 20, "Puppies": 90, "Snakes": 21, "Fish": 10, "Kittens": 67}]
total = 0
for diction in di:
    try:
        total = total + diction['Puppies']
    except Exception as e:
        diction["Puppies"]=0
        print('error')
print("Total number of puppies:", total)
# Out:
# error
# Total number of puppies: 130
