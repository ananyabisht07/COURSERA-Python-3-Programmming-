# %%
from IPython.display import Image

# %% [markdown]
# #                    **course_1_assessment_2**

# %% [markdown]
# Question1:

# %%
Image('week_1(1).JPG',width=800)

# %% [markdown]
# **This is the first question where you have to simply pass a parameter (i.e 5) to the function which is already defined in the textbook named 'square'.**

# %% [markdown]
# Question2:

# %%
Image('week_1(2).JPG',width=800)

# %% [markdown]
# **"len" in python is a function that can count the number of charecters in a string.So using len() we have calculates the number of characters of string "rv" and stored in variable "num_chars ".**

# %% [markdown]
# Question3:

# %%
Image('week_1(3).JPG',width=1500)

# %% [markdown]
# A:Though we are using the len function here, we are hardcoding what len should return the length of. We are not referencing z or y.
#
# B:This is hardcoding, we are writing in the value without referencing z or y.
#
# C:Though we are using the len function here, we are hardcoding what len should return the length of each time we call len. We are not referencing z or y
