# %%
from IPython.display import Image

# %% [markdown]
# # **course_1_assessment_3**

# %% [markdown]
# Question 1:

# %%
Image('assisment_3(1).JPG',width=1000)

# %% [markdown]
# Question 2:

# %%
Image('assisment_3(2).JPG',width=1100)

# %% [markdown]
# Question 3:

# %%
Image('assisment_3(3).JPG',width=1100)

# %% [markdown]
# Question 4:

# %%
Image('assisment_3(4).JPG',width=1100)

# %% [markdown]
# Question 5:

# %%
Image('assisment_3(5).JPG',width=1100)

# %% [markdown]
# Question 6:

# %%
Image('assisment_3(6).JPG',width=1100)

# %% [markdown]
# Question 7:

# %%
Image('assisment_3(7).JPG',width=1100)

# %% [markdown]
# Question 8:

# %%
Image('assisment_3(8).JPG',width=1100)
