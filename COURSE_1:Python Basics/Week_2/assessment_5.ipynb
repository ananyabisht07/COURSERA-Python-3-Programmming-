# %%
from IPython.display import Image

# %% [markdown]
# # **course_1_assessment_5**

# %% [markdown]
# Question:1

# %%
Image('ass5(1).JPG',width=1500)

# %%
let = "z"
let_two = "p"
c = let_two + let
m = c*5
print(m)
# Out:
# pzpzpzpzpz

# %% [markdown]
# Question:2

# %%
Image('ass5(2).JPG',width=1100)

# %%
sports = ['cricket', 'football', 'volleyball', 'baseball', 'softball', 'track and field', 'curling', 'ping pong', 'hockey']
last=sports[len(sports)-3:]
print(last)
# Out:
# ['curling', 'ping pong', 'hockey']

# %% [markdown]
# Question:3

# %%
Image('ass5(3).JPG',width=1100)

# %%
by = "You are"
az = "doing a great "
io = "job"
qy = "keep it up!"
message=by+" "+az+io+','+" "+qy
print(message)
# Out:
# You are doing a great job, keep it up!

# %% [markdown]
# Question:4

# %%
Image('ass5(4).JPG',width=1500)

# %%
ls = ['run', 'world', 'travel', 'lights', 'moon', 'baseball', 'sea']
new = ls[2:4]
print(new)
# Out:
# ['travel', 'lights']

# %% [markdown]
# Question:5

# %%
Image('ass5(5).JPG',width=1500)

# %%
l = ['w', '7', 0, 9]
m = l[1:2]
print(type(m))
# Out:
# <class 'list'>

# %% [markdown]
# Question:6

# %%
Image('ass5(8).JPG',width=1500)

# %%
l = ['w', '7', 0, 9]
m = l[1]
print(type(m))
# Out:
# <class 'str'>

# %% [markdown]
# Question:7

# %%
Image('ass5(6).JPG',width=1500)

# %%
b = "My, what a lovely day"
x = b.split(',')
type(x)
# Out:
# list

# %% [markdown]
# Question:8

# %%
Image('ass5(7).JPG',width=1500)

# %%
b = "My, what a lovely day"
x = b.split(',')
z = "".join(x)
y = z.split()
a = "".join(y)
print(type(a))
# Out:
# <class 'str'>
