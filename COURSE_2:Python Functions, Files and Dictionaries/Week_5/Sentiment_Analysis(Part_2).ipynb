# %%
from matplotlib import pyplot as plt

# %%
x=[0, 0, 1, 1, 2, 2, 2, -3, -2, 4, -1, 1, 2, 1, 1, 1, 3, 2, 0]
y=[3, 1, 1, 3, 6, 9, 19, 0, 0, 82, 0, 0, 47, 2, 0, 0, 4, 19, 0]
fig = plt.figure()
plt.scatter(x, y) 
fig.suptitle('Sample Sentiment Analysis Result', fontsize=20)
plt.xlabel('No. of Retweets', fontsize=18)
plt.ylabel('Net Sentiment Score', fontsize=16)
plt.grid()
